# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath ="C:/Users/psais/OneDrive/Desktop/sowmya/Subjects Sem 2/DataSets/marks -Classification of universty.txt"
df = pd.read_csv(filepath,sep=",",header= None)

# %%
df.rename(columns={0:"Marks1",1:"Marks2",2:"Admission Status"},inplace= True)

# %%
# X = feature values, all the columns except the last column
X = df.iloc[:, :-1]
#y = target values, last column of the data frame
Y = df.iloc[:, -1]

# %%
# filter out the applicants that got admitted
admitted = df.loc[Y == 1]

# %%
# filter out the applicants that din't get admission
not_admitted = df[Y == 0]

# %%
# plots
plt.figure(figsize=(10, 6))
x1_min, x1_max = X.iloc[:,0].min(), X.iloc[:,0].max(),
x2_min, x2_max = X.iloc[:,1].min(), X.iloc[:,1].max(),
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))
grid = np.c_[xx1.ravel(), xx2.ravel()]
probs = model.predict(grid).reshape(xx1.shape)
plt.scatter(admitted.iloc[:, 0], admitted.iloc[:, 1], s=25, label='Admitted')
plt.scatter(not_admitted.iloc[:, 0], not_admitted.iloc[:, 1], s=10, label='Not Admitted')
plt.contour(xx1, xx2, probs, [0.5], linewidths=1, colors='black')
plt.legend()

# %%
# the above graph shows Low Precision/High Recall i.e we want to reduce the number of false negatives without necessarily reducing the number false positives,

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
model = LogisticRegression()
model.fit(X, Y)
predicted_classes = model.predict(X)
accuracy = accuracy_score(Y,predicted_classes)
parameters = model.coef_

# %%
# skilearn logistic regression does regularisation to reduce overfitting.
